# %% [markdown]
# # NLP/Sentiment Analysis

# %% [markdown]
# ### Import Dependencies

# %%
from textblob import TextBlob
import pandas as pd
import random
# from collections import Counter
# import matplotlib.pyplot as plt

# %% [markdown]
# ### Connecting with MongoDB

# %%
# Importing dependencies to import datasets from MongoDB
from pymongo import MongoClient
import os

# %%
# Creating a connection with MongoDB
client=MongoClient('localhost', 27017)

# %%
# Providing list of datasets for US Elections Twitter data
db=client.us_election_twitter
collect_names=db.list_collection_names()
collect_names
# Out:
# ['romney3_12_df',
#  'mccain1_08_df',
#  'romney1_12_df',
#  'barack1_08_df',
#  'trump3_20_df',
#  'trump2_20_df',
#  'trump1_20_df',
#  'trump1_16_df',
#  'trump2_16_df',
#  'hillary2_16_df',
#  'romney2_12_df',
#  'biden1_20_df',
#  'biden2_20_df',
#  'barack3_12_df',
#  'biden3_20_df',
#  'mccain3_08_df',
#  'barack3_08_df',
#  'mccain2_08_df',
#  'hillary1_16_df',
#  'barack2_12_df',
#  'trump3_16_df',
#  'barack1_12_df',
#  'barack2_08_df',
#  'hillary3_16_df']

# %% [markdown]
# ### Importing Collections from MongoDB

# %%
data=db.biden2_20_df
h_list=data.find()
biden2_20=pd.DataFrame(list(data.find()))

# %%
data=db.trump2_20_df
h_list=data.find()
trump2_20=pd.DataFrame(list(data.find()))

# %%
# Keeping the following columns: 'tweet', 'replies_count', 'retweets_count', 'like_count'
biden2_20=pd.DataFrame(biden2_20, columns=['tweet','replies_count','retweets_count','likes_count'])
trump2_20=pd.DataFrame(trump2_20, columns=['tweet','replies_count','retweets_count','likes_count'])
biden2_20['candidate']='Biden' # Adding separate column to identify candidate
trump2_20['candidate']='Trump' # Adding separate column to identify candidate

# %% [markdown]
# ### Random Samples of Datasets

# %%
# # As this was a big data project we decided to choose random samples of 30 percent for each 
# # dataset to facilitate quicker analysis and lower the probability of slow machine performance
# biden3_20=biden3_20.sample(frac = 0.3)
# trump3_20=trump3_20.sample(frac = 0.3)

# %% [markdown]
# ### Preprocessing of Data

# %% [markdown]
# ### Create Funciton to Clean Tweets

# %%
# Import Dependency for RegEx
import re
# import emoji 

def cleantweet(text):
    text=re.sub(r'@[A-Za-z0-9_]+', '', text) # This removes @ mentions
    text=re.sub(r'https?:\/\/\S+', '', text) # This removes the hyperlinks
    text=re.sub(r'#[A-Za-z0-9_]+', '', text) # This removes the hashtag mentions
    text=re.sub(r'\W', ' ', text) # This removes all special characters
    text=re.sub(r'[^\x00-\x7F]+',' ', text) # This replaces non-ASCII characters with space
    text=re.sub(r'\s+[a-zA-Z]\s+', ' ', text) # Removing all single characters left as a result of removing all special characters
    text=re.sub(r'\^[a-zA-Z]\s+', ' ', text) # Removing all single characters from the start
    text=re.sub(r'_', '', text) # This removes underscore symbols
    text=re.sub(r'\s+', ' ', text, flags=re.I) # Replacing multiple spaces with single spaces
#     text = text.lower() # Converts all text to lowercase
#     text=emoji.get_emoji_regexp().sub(u'',text) # This removes the emojis
#     text=re.sub('\n', ' ', text) # This removes linebreaks
    return text

# %% [markdown]
# ### Creating Function to Drop Empty Tweets

# %%
import numpy as np
def drop_empty_tweets(db):
    db=db.replace(r'^\s*$', np.nan, regex=True) # Replace empty cells with NaN value
    return db

# %% [markdown]
# ### Cleaning tweets, dropping rows with NaN values and Creating New Column

# %%
# Applying function to clean tweets and drop empty tweets for Biden
biden2_20['tweet']=biden2_20['tweet'].apply(cleantweet)
biden2_20=biden2_20.apply(drop_empty_tweets)

# %%
# Applying function to clean tweets and drop empty tweets for Trump
trump2_20['tweet']=trump2_20['tweet'].apply(cleantweet)
trump2_20=trump2_20.apply(drop_empty_tweets)

# %% [markdown]
# ### Dropping NaN values

# %%
biden2=biden2_20.dropna()
trump2=trump2_20.dropna()

# %% [markdown]
# ### Creating Length of Tweets Feature

# %%
biden2['tweet'] = biden2['tweet'].astype(str) # Converting tweet column to string before splitting
biden2['tweet_length']= biden2['tweet'].str.split().str.len() # Creating separate column with length of tweets
# Out:
# C:\Users\Greg\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Greg\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
trump2['tweet'] = trump2['tweet'].astype(str) # Converting tweet column to string before splitting
trump2['tweet_length']= trump2['tweet'].str.split().str.len() # Creating separate column with length of tweets
# Out:
# C:\Users\Greg\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Greg\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ### Joining both Biden and Trump Datasets

# %%
# Joining both Biden and Trump Datasets
second_debate=pd.concat([biden2,trump2])
second_debate.count()
# Out:
# tweet             995049
# replies_count     995049
# retweets_count    995049
# likes_count       995049
# candidate         995049
# tweet_length      995049
# dtype: int64

# %%
# Create function to obtain subjectivity
def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity

# Create function to obtain polarity
def getPolarity(text):
    return TextBlob(text).sentiment.polarity

# Create Columns for Subjectivity and Polarity
second_debate['Subjectivity']=second_debate['tweet'].apply(getSubjectivity)
second_debate['Polarity']=second_debate['tweet'].apply(getPolarity)
second_debate.head(60)
# Out:
#                                                 tweet  replies_count  \
# 0   Hypothetical Question Let say Joe Biden wins t...              0
# 1                          want the Healthcare fixed               0
# 2   Joe Biden and Kamala Harris will not let Donal...              0
# 3   Apparently thinks being compared to Mister Rog...              0
# 4    And Joe Biden doesn break the law mon Donkey ...              0
# 5    Ofcourse But it will literally always be like...              1
# 6    Sure it could We don even know how much debt ...              1
# 7   Texting is easy if you re not comfortable with...              0
# 8    All m saying is not everyone can be in manage...              1
# 9                   Lock up He a liar fraud criminal               0
# 10   Hum Let see Trump is behind everywhere and do...              0
# 12   m having sex with mel high for an eternity th...              0
# 13   think he going to have his hands full with Tr...              0
# 14                                      It Joe Biden               1
# 15   Hunter supports LBGTQ right too or are you sp...              0
# 16                                         Muslim ban              0
# 17   What was insinuating is you have an illogical...              1
# 18  Peter Schweizer Emails confirm China Ukraine b...              0
# 19   He said this last night at his town hall so yes               1
# 22                    Immigration enforcement by ICE               0
# 23  Report Joe Biden met with Hunter Ukraine busin...              0
# 24              And now he supports racist homophobe               1
# 25   Biden was one of the first senators to suppor...              4
# 26   Minimum wages only being intended for high sc...              1
# 27   agree Vote for Joe Biden the man of integrity...              0
# 28   want Joe Biden to put safeguards in place tha...              3
# 29   This is what leadership compassion and human ...              0
# 30   If your response to her pain begins with the ...              0
# 31  i wish trump died wish joe biden would die too...              1
# 32   If for some stupid reason you don win we ll t...             11
# 33   your lies ne Er stop do hurtful for people wh...              0
# 34   Revoke ALL IMPOTUS45 Executive Orders Then ar...              0
# 35                            that all for you smiley              0
# 37   We want to hear about your son and his dealin...              0
# 38             Transphobia IS THAT IN THE SCRIPTURES               1
# 39   Keep your eyes on the ACA and not what Biden ...              0
# 40   Who are these parents that makes these decisi...              1
# 41                                  It the cap for me              0
# 42   He won get hard your not 12 anymore likes the...              0
# 43   10 to be held by the big guy Joe this is bad ...              0
# 44      Don you think that Biden has white supremacy               0
# 45   So this starts with god and guns Peters has n...              6
# 46                       The lying criminal Joe Biden              0
# 47   He delusional alright Bc he the one with his ...              0
# 48                JOE BIDEN T TH TRUNG NG TH T V I T               0
# 49   Hey Jon do you know how desperate this tweet ...              5
# 50  Avoiding everyone from Connecticut who votes f...              0
# 51   Lost his accomplishments maybe meant lost if ...              0
# 53   Ummm don know about testing in your area But ...              1
# 54  Maybe before fact checkers at call liar they s...              0
# 55   at is an She says if the election were held t...              0
# 56  Hunter enriching himself Snorting blow off of ...              0
# 57   Like when you threatened to withhold 1B from ...              0
# 58   BREAKING Secret audio tapes of Hunter amp Joe...              0
# 59   will vote for Joe Biden cannot support Presid...              0
# 60                                               Lier              0
# 61                It was under OBAMA it was legalized              1
# 62                     trump has done nothing period               1
# 63  Chip in to elect Joe Biden and other Democrats...              0
# 64   So your saying trump should get at least 160 ...              0
#
#     retweets_count  likes_count candidate  tweet_length  Subjectivity  \
# 0                0            0     Biden            48      0.287500
# 1                0            0     Biden             4      0.200000
# 2                1            1     Biden            25      0.383333
# 3                0            0     Biden            17      0.305000
# 4                0            3     Biden            10      0.000000
# 5                0            0     Biden            20      0.583333
# 6                0            0     Biden            36      0.620370
# 7                0            0     Biden            11      0.816667
# 8                1            2     Biden            53      0.350000
# 9                0            0     Biden             7      0.550000
# 10               0            3     Biden            42      0.604921
# 12               0            0     Biden            17      0.713333
# 13               0            0     Biden            13      0.550000
# 14               0            0     Biden             3      0.000000
# 15               0            2     Biden            10      0.535714
# 16               0            0     Biden             2      0.000000
# 17               0            0     Biden            38      0.366667
# 18               1            1     Biden            11      0.000000
# 19               0            1     Biden            11      0.066667
# 22               0            0     Biden             4      0.000000
# 23               0            0     Biden            24      0.000000
# 24               0            5     Biden             6      0.000000
# 25               0           15     Biden            15      0.566667
# 26               0            3     Biden            36      0.635000
# 27               0            0     Biden            45      1.000000
# 28               5           22     Biden            50      0.166667
# 29               5           35     Biden            11      0.100000
# 30               0            7     Biden            16      0.333333
# 31               0            0     Biden            28      0.800000
# 32               0           12     Biden            28      0.700000
# 33               0            0     Biden            13      0.000000
# 34               0            1     Biden             8      0.000000
# 35               0            1     Biden             5      0.000000
# 37               0            0     Biden            12      0.000000
# 38               0            2     Biden             6      0.000000
# 39               0            0     Biden            19      0.000000
# 40               0            0     Biden            18      0.200000
# 41               0           15     Biden             5      0.000000
# 42               0            0     Biden            11      0.470833
# 43               0            0     Biden            15      0.383333
# 44               0            1     Biden             8      0.000000
# 45               0            0     Biden            23      0.450000
# 46               0            0     Biden             5      0.550000
# 47               0            0     Biden            18      0.540000
# 48               0            0     Biden            11      0.000000
# 49               1           16     Biden            16      1.000000
# 50               0            0     Biden             9      0.000000
# 51               0            0     Biden            16      1.000000
# 53               0            1     Biden            47      0.287500
# 54               0            0     Biden            26      0.496296
# 55               0            0     Biden            45      0.660000
# 56               0            0     Biden             9      0.000000
# 57               0            0     Biden             9      0.000000
# 58               2            5     Biden            44      0.833333
# 59               0            0     Biden            37      0.347917
# 60               0            0     Biden             1      0.000000
# 61               0            0     Biden             7      0.000000
# 62               0            6     Biden             5      0.000000
# 63               0            1     Biden            12      0.637500
# 64               0            0     Biden            11      0.400000
#
#         Polarity
# 0   2.156250e-01
# 1   1.000000e-01
# 2  -2.000000e-01
# 3   1.550000e-01
# 4   0.000000e+00
# 5  -1.000000e-01
# 6   5.555556e-02
# 7   1.166667e-01
# 8   2.000000e-01
# 9  -4.000000e-01
# 10 -5.396825e-02
# 12  3.866667e-01
# 13  3.500000e-01
# 14  0.000000e+00
# 15  2.857143e-01
# 16  0.000000e+00
# 17 -1.666667e-01
# 18  0.000000e+00
# 19  0.000000e+00
# 22  0.000000e+00
# 23  0.000000e+00
# 24  0.000000e+00
# 25 -2.750000e-01
# 26  1.441667e-01
# 27 -1.000000e+00
# 28  2.500000e-02
# 29  0.000000e+00
# 30  0.000000e+00
# 31  3.500000e-01
# 32  5.551115e-17
# 33  0.000000e+00
# 34 -5.000000e-02
# 35  0.000000e+00
# 37  0.000000e+00
# 38  0.000000e+00
# 39  0.000000e+00
# 40  1.000000e-01
# 41  0.000000e+00
# 42 -9.583333e-02
# 43 -3.500000e-01
# 44  0.000000e+00
# 45  3.000000e-01
# 46 -4.000000e-01
# 47  1.600000e-01
# 48  0.000000e+00
# 49 -3.000000e-01
# 50  0.000000e+00
# 51 -5.000000e-01
# 53  2.250000e-01
# 54  3.000000e-01
# 55  2.200000e-01
# 56  0.000000e+00
# 57  0.000000e+00
# 58 -5.333333e-01
# 59  3.125000e-02
# 60  0.000000e+00
# 61  0.000000e+00
# 62  0.000000e+00
# 63  3.375000e-01
# 64 -3.000000e-01

# %%
# Obtaining Polarity Analysis
def getPolarityAnalysis(score):
    if score < 0:
        return 'Negative'
    elif score == 0:
        return 'Neutral'
    else:
        return 'Positive'
    
second_debate['Sentiment']=second_debate['Polarity'].apply(getPolarityAnalysis)
second_debate.head(60)
# Out:
#                                                 tweet  replies_count  \
# 0   Hypothetical Question Let say Joe Biden wins t...              0
# 1                          want the Healthcare fixed               0
# 2   Joe Biden and Kamala Harris will not let Donal...              0
# 3   Apparently thinks being compared to Mister Rog...              0
# 4    And Joe Biden doesn break the law mon Donkey ...              0
# 5    Ofcourse But it will literally always be like...              1
# 6    Sure it could We don even know how much debt ...              1
# 7   Texting is easy if you re not comfortable with...              0
# 8    All m saying is not everyone can be in manage...              1
# 9                   Lock up He a liar fraud criminal               0
# 10   Hum Let see Trump is behind everywhere and do...              0
# 12   m having sex with mel high for an eternity th...              0
# 13   think he going to have his hands full with Tr...              0
# 14                                      It Joe Biden               1
# 15   Hunter supports LBGTQ right too or are you sp...              0
# 16                                         Muslim ban              0
# 17   What was insinuating is you have an illogical...              1
# 18  Peter Schweizer Emails confirm China Ukraine b...              0
# 19   He said this last night at his town hall so yes               1
# 22                    Immigration enforcement by ICE               0
# 23  Report Joe Biden met with Hunter Ukraine busin...              0
# 24              And now he supports racist homophobe               1
# 25   Biden was one of the first senators to suppor...              4
# 26   Minimum wages only being intended for high sc...              1
# 27   agree Vote for Joe Biden the man of integrity...              0
# 28   want Joe Biden to put safeguards in place tha...              3
# 29   This is what leadership compassion and human ...              0
# 30   If your response to her pain begins with the ...              0
# 31  i wish trump died wish joe biden would die too...              1
# 32   If for some stupid reason you don win we ll t...             11
# 33   your lies ne Er stop do hurtful for people wh...              0
# 34   Revoke ALL IMPOTUS45 Executive Orders Then ar...              0
# 35                            that all for you smiley              0
# 37   We want to hear about your son and his dealin...              0
# 38             Transphobia IS THAT IN THE SCRIPTURES               1
# 39   Keep your eyes on the ACA and not what Biden ...              0
# 40   Who are these parents that makes these decisi...              1
# 41                                  It the cap for me              0
# 42   He won get hard your not 12 anymore likes the...              0
# 43   10 to be held by the big guy Joe this is bad ...              0
# 44      Don you think that Biden has white supremacy               0
# 45   So this starts with god and guns Peters has n...              6
# 46                       The lying criminal Joe Biden              0
# 47   He delusional alright Bc he the one with his ...              0
# 48                JOE BIDEN T TH TRUNG NG TH T V I T               0
# 49   Hey Jon do you know how desperate this tweet ...              5
# 50  Avoiding everyone from Connecticut who votes f...              0
# 51   Lost his accomplishments maybe meant lost if ...              0
# 53   Ummm don know about testing in your area But ...              1
# 54  Maybe before fact checkers at call liar they s...              0
# 55   at is an She says if the election were held t...              0
# 56  Hunter enriching himself Snorting blow off of ...              0
# 57   Like when you threatened to withhold 1B from ...              0
# 58   BREAKING Secret audio tapes of Hunter amp Joe...              0
# 59   will vote for Joe Biden cannot support Presid...              0
# 60                                               Lier              0
# 61                It was under OBAMA it was legalized              1
# 62                     trump has done nothing period               1
# 63  Chip in to elect Joe Biden and other Democrats...              0
# 64   So your saying trump should get at least 160 ...              0
#
#     retweets_count  likes_count candidate  tweet_length  Subjectivity  \
# 0                0            0     Biden            48      0.287500
# 1                0            0     Biden             4      0.200000
# 2                1            1     Biden            25      0.383333
# 3                0            0     Biden            17      0.305000
# 4                0            3     Biden            10      0.000000
# 5                0            0     Biden            20      0.583333
# 6                0            0     Biden            36      0.620370
# 7                0            0     Biden            11      0.816667
# 8                1            2     Biden            53      0.350000
# 9                0            0     Biden             7      0.550000
# 10               0            3     Biden            42      0.604921
# 12               0            0     Biden            17      0.713333
# 13               0            0     Biden            13      0.550000
# 14               0            0     Biden             3      0.000000
# 15               0            2     Biden            10      0.535714
# 16               0            0     Biden             2      0.000000
# 17               0            0     Biden            38      0.366667
# 18               1            1     Biden            11      0.000000
# 19               0            1     Biden            11      0.066667
# 22               0            0     Biden             4      0.000000
# 23               0            0     Biden            24      0.000000
# 24               0            5     Biden             6      0.000000
# 25               0           15     Biden            15      0.566667
# 26               0            3     Biden            36      0.635000
# 27               0            0     Biden            45      1.000000
# 28               5           22     Biden            50      0.166667
# 29               5           35     Biden            11      0.100000
# 30               0            7     Biden            16      0.333333
# 31               0            0     Biden            28      0.800000
# 32               0           12     Biden            28      0.700000
# 33               0            0     Biden            13      0.000000
# 34               0            1     Biden             8      0.000000
# 35               0            1     Biden             5      0.000000
# 37               0            0     Biden            12      0.000000
# 38               0            2     Biden             6      0.000000
# 39               0            0     Biden            19      0.000000
# 40               0            0     Biden            18      0.200000
# 41               0           15     Biden             5      0.000000
# 42               0            0     Biden            11      0.470833
# 43               0            0     Biden            15      0.383333
# 44               0            1     Biden             8      0.000000
# 45               0            0     Biden            23      0.450000
# 46               0            0     Biden             5      0.550000
# 47               0            0     Biden            18      0.540000
# 48               0            0     Biden            11      0.000000
# 49               1           16     Biden            16      1.000000
# 50               0            0     Biden             9      0.000000
# 51               0            0     Biden            16      1.000000
# 53               0            1     Biden            47      0.287500
# 54               0            0     Biden            26      0.496296
# 55               0            0     Biden            45      0.660000
# 56               0            0     Biden             9      0.000000
# 57               0            0     Biden             9      0.000000
# 58               2            5     Biden            44      0.833333
# 59               0            0     Biden            37      0.347917
# 60               0            0     Biden             1      0.000000
# 61               0            0     Biden             7      0.000000
# 62               0            6     Biden             5      0.000000
# 63               0            1     Biden            12      0.637500
# 64               0            0     Biden            11      0.400000
#
#         Polarity Sentiment
# 0   2.156250e-01  Positive
# 1   1.000000e-01  Positive
# 2  -2.000000e-01  Negative
# 3   1.550000e-01  Positive
# 4   0.000000e+00   Neutral
# 5  -1.000000e-01  Negative
# 6   5.555556e-02  Positive
# 7   1.166667e-01  Positive
# 8   2.000000e-01  Positive
# 9  -4.000000e-01  Negative
# 10 -5.396825e-02  Negative
# 12  3.866667e-01  Positive
# 13  3.500000e-01  Positive
# 14  0.000000e+00   Neutral
# 15  2.857143e-01  Positive
# 16  0.000000e+00   Neutral
# 17 -1.666667e-01  Negative
# 18  0.000000e+00   Neutral
# 19  0.000000e+00   Neutral
# 22  0.000000e+00   Neutral
# 23  0.000000e+00   Neutral
# 24  0.000000e+00   Neutral
# 25 -2.750000e-01  Negative
# 26  1.441667e-01  Positive
# 27 -1.000000e+00  Negative
# 28  2.500000e-02  Positive
# 29  0.000000e+00   Neutral
# 30  0.000000e+00   Neutral
# 31  3.500000e-01  Positive
# 32  5.551115e-17  Positive
# 33  0.000000e+00   Neutral
# 34 -5.000000e-02  Negative
# 35  0.000000e+00   Neutral
# 37  0.000000e+00   Neutral
# 38  0.000000e+00   Neutral
# 39  0.000000e+00   Neutral
# 40  1.000000e-01  Positive
# 41  0.000000e+00   Neutral
# 42 -9.583333e-02  Negative
# 43 -3.500000e-01  Negative
# 44  0.000000e+00   Neutral
# 45  3.000000e-01  Positive
# 46 -4.000000e-01  Negative
# 47  1.600000e-01  Positive
# 48  0.000000e+00   Neutral
# 49 -3.000000e-01  Negative
# 50  0.000000e+00   Neutral
# 51 -5.000000e-01  Negative
# 53  2.250000e-01  Positive
# 54  3.000000e-01  Positive
# 55  2.200000e-01  Positive
# 56  0.000000e+00   Neutral
# 57  0.000000e+00   Neutral
# 58 -5.333333e-01  Negative
# 59  3.125000e-02  Positive
# 60  0.000000e+00   Neutral
# 61  0.000000e+00   Neutral
# 62  0.000000e+00   Neutral
# 63  3.375000e-01  Positive
# 64 -3.000000e-01  Negative

# %% [markdown]
# ### Convert ML_Data to CSV

# %%
second_debate.to_csv(r'C:\Users\Greg\Documents\Analysis_Projects\US_Election_NLP\US_Election_NLP\Concat_ML_Data\second_debate.csv', index = False, header=True)
